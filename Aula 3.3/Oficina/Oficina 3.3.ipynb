# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
uri = 'https://d11s0xq1vqg039.cloudfront.net/videos_conteudo/visual/micro07/oficina/arquivos/dadosoficina07.txt'
shampoo = pd.read_csv(uri)
shampoo.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
plt.figure(figsize=(10,5))
plt.style.use("ggplot")
plt.title('Vendas ao longo dos meses')
plt.xticks(rotation = 45) #Rotacionando os nomes para poderem ser lidos
sns.lineplot(x="Month", y="Sales", data=shampoo)
plt.show()
